# %% [markdown]
# 1) Массив из 64 случайных целых чисел в случайном порядке
#
# 2) На основе этого массива строим бинарное дерево (относительно первого элемента массива)
# Отобразить дерево
#
# 3) Обойти в ширину (вывести массив)
#
#  обойти в глубину (вывести массив)
#
# 4) Удалить узел(не корень) с поддеревом

# %%
class Node:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
    def insert(root, val):
        current = root

        while current != None
